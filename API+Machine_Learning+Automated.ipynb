# %% [markdown]
# <a href="https://colab.research.google.com/github/siva-Parvathi-M/Siva/blob/main/API%2BMachine_Learning%2BAutomated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/Colab Notebooks/Source Data/house_prices.csv"  # Change this to your actual file path
df = pd.read_csv(file_path)

print(df.head())  # Display first 5 rows
# Out:
#    Size   Price
# 0   800  150000
# 1  1000  180000
# 2  1200  210000
# 3  1500  250000
# 4  1800  290000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Source Data/house_prices.csv")

# %%
print("Dataset Preview:")
print(df.head())
# Out:
# Dataset Preview:
#    Size   Price
# 0   800  150000
# 1  1000  180000
# 2  1200  210000
# 3  1500  250000
# 4  1800  290000

# %% [markdown]
# **Select features (X) and target (Y)**

# %%
X = df[['Size']]  # Feature: House Size (Use "Size" instead of "size")
Y = df['Price']   # Target: House Price (Use "Price" instead of "price")

print("Feature and Target selected successfully!")
# Out:
# Feature and Target selected successfully!

# %% [markdown]
# **Train the Linear Regression Model**

# %%
from sklearn.linear_model import LinearRegression

# Create a Linear Regression model
model = LinearRegression()

# Train (fit) the model with the data
model.fit(X, Y)

print("Model training completed successfully!")
# Out:
# Model training completed successfully!

# %% [markdown]
# **Make Predictions with the Model**

# %%
# Predict the price of a house with a size of 1300 sq ft
predicted_price = model.predict([[1300]])

print(f"Predicted Price for 1300 sq ft house: ${predicted_price[0]:.2f}")
# Out:
# Predicted Price for 1300 sq ft house: $221827.00
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Visualize the Regression Model python Copy Edit**

# %%
import matplotlib.pyplot as plt

# Plot actual data points
plt.scatter(df["Size"], df["Price"], color="blue", label="Actual Data")

# Plot regression line
plt.plot(df["Size"], model.predict(df[["Size"]]), color="red", label="Prediction Line")

# Mark the predicted point
plt.scatter(1300, predicted_price, color="green", marker="o", label="Predicted Price (1300 sq ft)")

# Labels and legend
plt.xlabel("House Size (sq ft)")
plt.ylabel("House Price ($)")
plt.title("House Price Prediction using Linear Regression")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# **Evaluating Model Performance**

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Predictions on training data
y_pred = model.predict(X)

# Calculate evaluation metrics
mae = mean_absolute_error(Y, y_pred)  # Mean Absolute Error
mse = mean_squared_error(Y, y_pred)  # Mean Squared Error
rmse = mse ** 0.5  # Root Mean Squared Error
r2 = r2_score(Y, y_pred)  # R-squared Score

# Print the metrics
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-Squared Score (R²): {r2:.4f}")  # Closer to 1 means better fit
# Out:
# Mean Absolute Error (MAE): 1082.23
# Mean Squared Error (MSE): 1958882.85
# Root Mean Squared Error (RMSE): 1399.60
# R-Squared Score (R²): 0.9998

# %% [markdown]
# **Automating Predictions**

# %%
import pandas as pd

# Function to predict price based on user input
def predict_price():
    size = float(input("Enter house size: "))
    size_df = pd.DataFrame({'Size': [size]})  # Convert input into DataFrame with correct column name
    predicted_price = model.predict(size_df)[0]  # Now fits expected format
    print(f"Predicted Price for {size} sq ft house: ${predicted_price:.2f}")

# Run the function
predict_price()
# Out:
# Enter house size: 1500
# Predicted Price for 1500.0 sq ft house: $249817.69

# %% [markdown]
# **Let's visualize the predictions first! 📊**

# %%
import matplotlib.pyplot as plt

# Scatter plot of actual data
plt.scatter(X, Y, color='blue', label="Actual Data")

# Plot the regression line
plt.plot(X, model.predict(X), color='red', linewidth=2, label="Regression Line")

# Labels and title
plt.xlabel("House Size (sq ft)")
plt.ylabel("House Price ($)")
plt.title("Linear Regression Model")
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# **Save the Trained Model**

# %%
import joblib

# Save the trained model
joblib.dump(model, "house_price_model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %% [markdown]
# **Load the Saved Model**

# %%
# Load the trained model
loaded_model = joblib.load("house_price_model.pkl")

# Predict using the loaded model
house_size = float(input("Enter house size: "))
predicted_price = loaded_model.predict([[house_size]])
print(f"Predicted Price for {house_size} sq ft house: ${predicted_price[0]:,.2f}")
# Out:
# Enter house size: 1650
# Predicted Price for 1650.0 sq ft house: $270,810.71
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import joblib  # For loading the model

# Load the trained model
loaded_model = joblib.load("house_price_model.pkl")

# Take user input
house_size = float(input("Enter house size: "))

# Convert input to a DataFrame with the same column name used in training
input_data = pd.DataFrame({'Size': [house_size]})  # Match case-sensitive column name

# Predict house price
predicted_price = loaded_model.predict(input_data)

# Display the result
print(f"Predicted Price for {house_size} sq ft house: ${predicted_price[0]:,.2f}")
# Out:
# Enter house size: 2000
# Predicted Price for 2000.0 sq ft house: $319,794.41
